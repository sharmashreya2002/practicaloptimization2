# %%
import numpy as np
import random
import math

def move(x, D):
    """Move the state vector ."""
    u = np.random.uniform(-1, 1, len(x))
    alpha = 0.1
    w = 2.1
    R = np.diag(np.dot(D, u))
    D = (1 - alpha) * D + alpha * w * R
    min_step_size = 1e-6 #FIX
    D = np.where(D < min_step_size, min_step_size, D)
    x = x + np.dot(D, u)
    return x, D, u

def objective(x, n):
    """Keane's Bump function.
    n = dimension of the domain
    x = vector in the domain"""
    cos4 = 0
    cos2 = 1
    x_i = 0
    for i in range(n):
        cos4 += math.cos(x[i])**4
        cos2 *= math.cos(x[i])**2
        x_i += (i+1)*(x[i]**2)
    if x_i == 0:
        answer = None
    else:
        answer = np.abs((cos4 - 2*cos2)/math.sqrt(x_i))
    ## we are turning the maximization problem into a minimization problem
    return -1 * answer

def assess_solution(x_prev, n, D_prev, T):
    f_prev = objective(x_prev, n)
    x, D, u = move(x_prev, D_prev)
    ## test constraints and reject move, if necessary
    multiplicative_constraint = 1
    additive_constraint = 0
    for i in range(n):
        multiplicative_constraint *= x[i]
        additive_constraint += x[i]
        if x[i] < 0 or x[i] > 10:
            return x_prev, D_prev
    if multiplicative_constraint <= 0.75 or additive_constraint <= (15*n/2):
        return x_prev, D_prev
    f = objective(x, n)
    if f < f_prev:
        return x, D
    else:
        step_size = np.sqrt(np.sum(np.dot(D, u)**2))
        acceptance_prob = np.exp((f_prev - f)/(T*step_size))
        if random.random() < acceptance_prob:
            return x, D
        else:
            return x_prev, D_prev

def temperature_schedule(T, alpha_T):
    return alpha_T*T

def archive(x, f, archive):
    archive_limit = 10
    if len(archive) < archive_limit:
        archive.append((x, f))
    else:
        for i in range(archive_limit):
            if f < archive[i][1]:
                archive[i] = (x, f)
                break
    return archive

def main(x, n):
    ## initialize covariance matrix
    D = 0.5 * np.identity(n)
    ## initial temperature (FIX)
    T = 1000
    ## final temperature (FIX)
    T_min = 0.1
    ## min acceptance ratio (HYPER PARAMETER)
    min_acceptance_ratio = 0.1
    ## cooling rate (HYPER PARAMETER)
    alpha_T = 0.95
    ## markov chain length (HYPER PARAMETER)
    Lk = 100
    nmin = Lk *0.6

    ## initailize state, covariance matrix
    x_prev = x
    D_prev = D
    ## max number of iterations
    max_iter = 10000
    counter = 0
    ## initialize archive
    archive = []

    while T > T_min:
        acceptances = 0
        ## when either Lk trials or nmin acceptances whichever comes first, decrement the temperature 
        for i in range(Lk):
            x, D = assess_solution(x_prev, n, D_prev, T)
            if not np.array_equal(x, x_prev):
                acceptances += 1
                archive = archive(x, objective(x, n), archive)
            counter += 1
            if acceptances == nmin:
                break
        ## decrement temperature
        T = temperature_schedule(T, alpha_T)
        ## update state, covariance matrix
        x_prev = x
        D_prev = D
        ## no accepted moves in Lk iterations at temperature Tk
        if acceptances/ Lk <= min_acceptance_ratio:
            break
        if counter == max_iter:
            break
    return archive

# %% [markdown]
# We need to solve for the initial temperature, the initial solution, and the final temperature. We need to allocate minimum step sizes

# %%
import numpy as np
import random
import math

def move(x, D):
    """Move the state vector ."""
    u = np.random.uniform(-1, 1, len(x))
    alpha = 0.1
    w = 2.1
    R = np.diag(np.dot(D, u))
    D = (1 - alpha) * D + alpha * w * R
    min_step_size = 1e-6 #FIX
    D = np.where(D < min_step_size, min_step_size, D)
    x = x + np.dot(D, u)
    return x, D, u

def objective(x, n):
    """Keane's Bump function.
    n = dimension of the domain
    x = vector in the domain"""
    cos4 = 0
    cos2 = 1
    x_i = 0
    for i in range(n):
        cos4 += math.cos(x[i])**4
        cos2 *= math.cos(x[i])**2
        x_i += (i+1)*(x[i]**2)
    if x_i == 0:
        answer = None
    else:
        answer = np.abs((cos4 - 2*cos2)/math.sqrt(x_i))
    ## we are turning the maximization problem into a minimization problem
    return -1 * answer

def assess_solution(x_prev, n, D_prev, T):
    f_prev = objective(x_prev, n)
    x, D, u = move(x_prev, D_prev)
    ## test constraints and reject move, if necessary
    multiplicative_constraint = 1
    additive_constraint = 0
    for i in range(n):
        multiplicative_constraint *= x[i]
        additive_constraint += x[i]
        if x[i] < 0 or x[i] > 10:
            print(f"constraint 0 < x[i] < 10 violated, move rejected")
            return x_prev, D_prev
    if multiplicative_constraint <= 0.75 or additive_constraint >= (15*n/2):
        print(f"mulitplicative constraint or additive constraint violated, move rejected")
        return x_prev, D_prev
    f = objective(x, n)
    if f < f_prev:
        print(f"decreases f, move accepted")
        return x, D
    else:
        step_size = np.sqrt(np.sum(np.dot(D, u)**2))
        acceptance_prob = np.exp((f_prev - f)/(T*step_size))
        if random.random() < acceptance_prob:
            print(f"increases f, BUT move accepted")
            return x, D
        else:
            print(f"increases f, move rejected")
            return x_prev, D_prev

def temperature_schedule(T, alpha_T):
    return alpha_T*T

def archive_function(x, f, archive):
    archive_limit = 10
    if len(archive) < archive_limit:
        archive.append((x, f))
    else:
        for i in range(archive_limit):
            if f < archive[i][1]:
                archive[i] = (x, f)
                break
    return archive

def main(x, n):
    ## initialize covariance matrix
    D = 0.5 * np.identity(n)
    ## initial temperature (FIX)
    T = 1000
    ## final temperature (FIX)
    T_min = 0.1
    ## min acceptance ratio (HYPER PARAMETER)
    min_acceptance_ratio = 0.1
    ## cooling rate (HYPER PARAMETER)
    alpha_T = 0.95
    ## markov chain length (HYPER PARAMETER)
    Lk = 100
    nmin = Lk *0.6

    ## initailize state, covariance matrix
    x_prev = x
    D_prev = D
    ## max number of iterations
    max_iter = 2
    counter = 0
    ## initialize archive
    archive = []

    while T > T_min:
        acceptances = 0
        ## when either Lk trials or nmin acceptances whichever comes first, decrement the temperature 
        for i in range(Lk):
            x, D = assess_solution(x_prev, n, D_prev, T)
            if not np.array_equal(x, x_prev):
                acceptances += 1
                archive = archive_function(x, objective(x, n), archive)
                x_prev = x
                D_prev = D
            counter += 1
            if acceptances == nmin:
                break
        ## decrement temperature
        T = temperature_schedule(T, alpha_T)
        ## update state, covariance matrix
        x_prev = x
        D_prev = D
        print(f"temperature: {T}, acceptances: {acceptances}, counter: {counter}")
        ## no accepted moves in Lk iterations at temperature Tk
        if acceptances/ Lk <= min_acceptance_ratio:
            break
        if counter == max_iter:
            break
    return archive

# %%
print(main(np.array([2,2]), 2))
# Out:
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# temperature: 950.0, acceptances: 60, counter: 60
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# temperature: 902.5, acceptances: 60, counter: 120
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# temperature: 857.375, acceptances: 60, counter: 180
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# temperature: 814.5062499999999, acceptances: 60, counter: 241
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# temperature: 773.7809374999998, acceptances: 60, counter: 301
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# temperature: 735.0918906249998, acceptances: 60, counter: 361
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# temperature: 698.3372960937497, acceptances: 60, counter: 421
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# temperature: 663.4204312890622, acceptances: 60, counter: 481
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# temperature: 630.2494097246091, acceptances: 60, counter: 541
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# temperature: 598.7369392383787, acceptances: 60, counter: 601
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# temperature: 568.8000922764597, acceptances: 60, counter: 661
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# temperature: 540.3600876626367, acceptances: 60, counter: 721
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# temperature: 513.3420832795049, acceptances: 60, counter: 781
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# temperature: 487.6749791155296, acceptances: 60, counter: 841
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# temperature: 463.29123015975307, acceptances: 60, counter: 901
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# temperature: 440.1266686517654, acceptances: 60, counter: 961
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# temperature: 418.1203352191771, acceptances: 60, counter: 1021
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# temperature: 397.2143184582182, acceptances: 60, counter: 1081
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# temperature: 377.3536025353073, acceptances: 60, counter: 1141
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# temperature: 358.4859224085419, acceptances: 60, counter: 1201
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# temperature: 340.5616262881148, acceptances: 60, counter: 1261
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# temperature: 323.533544973709, acceptances: 60, counter: 1321
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# temperature: 307.35686772502356, acceptances: 60, counter: 1381
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# temperature: 291.98902433877237, acceptances: 60, counter: 1441
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# temperature: 277.38957312183373, acceptances: 60, counter: 1501
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, move rejected
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# temperature: 263.52009446574203, acceptances: 60, counter: 1562
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# ...
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, BUT move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# temperature: 0.12636619990554943, acceptances: 55, counter: 11679
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# temperature: 0.12004788991027195, acceptances: 53, counter: 11779
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# temperature: 0.11404549541475835, acceptances: 50, counter: 11879
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, BUT move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, BUT move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, BUT move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# temperature: 0.10834322064402042, acceptances: 50, counter: 11979
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# temperature: 0.1029260596118194, acceptances: 54, counter: 12079
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, BUT move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, BUT move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# decreases f, move accepted
# decreases f, move accepted
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# increases f, move rejected
# decreases f, move accepted
# increases f, move rejected
# temperature: 0.09777975663122843, acceptances: 53, counter: 12179
# [(array([3.13185548, 1.96650903]), -0.17303622842294947), (array([3.11648471, 1.97935269]), -0.16905502376819975), (array([3.18855076, 1.97786958]), -0.16676671702887627), (array([3.19756518, 1.97939217]), -0.16564052232583085), (array([3.21782846, 1.97842279]), -0.16431015496666557), (array([3.25667608, 1.9787322 ]), -0.16022082419466208), (array([3.31043574, 1.97514282]), -0.15409730872870672), (array([3.3323734 , 1.97107225]), -0.15183792227240875), (array([3.33226589, 1.97169148]), -0.1516699120464246), (array([3.33229091, 1.9717165 ]), -0.1516582487115711)]
